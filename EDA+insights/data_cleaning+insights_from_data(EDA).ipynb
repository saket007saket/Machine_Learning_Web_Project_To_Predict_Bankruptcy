# %% [markdown]
# ## 1.importing the important libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## 2. reading the files

# %%
year_1=pd.read_csv(r"C:\Users\SAKET NANDAN\Documents\current_hackathon\bank_ruptcy\Bankruptcy dataset\1year.csv")
year_2=pd.read_csv(r"C:\Users\SAKET NANDAN\Documents\current_hackathon\bank_ruptcy\Bankruptcy dataset\2year.csv")
year_3=pd.read_csv(r"C:\Users\SAKET NANDAN\Documents\current_hackathon\bank_ruptcy\Bankruptcy dataset\3year.csv")
year_4=pd.read_csv(r"C:\Users\SAKET NANDAN\Documents\current_hackathon\bank_ruptcy\Bankruptcy dataset\4year.csv")
year_5=pd.read_csv(r"C:\Users\SAKET NANDAN\Documents\current_hackathon\bank_ruptcy\Bankruptcy dataset\5year.csv")
# Out:
# C:\Users\SAKET NANDAN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,1,2,5,6,8,9,10,13,17,21,23,24,28,34,35,37,47,50,54,56,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\SAKET NANDAN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (14,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\SAKET NANDAN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,1,2,5,6,7,9,10,13,14,15,16,17,21,23,24,25,28,33,34,35,37,47,49,50,56,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ###### since, there are '?' characters present in each year dataset , so i m here replacing thise '?' with np.nan

# %%
k1=year_1.columns.tolist()

# %%
for i in k1:
    year_1[i] = year_1[i].replace('?',np.nan)
    year_2[i] = year_2[i].replace('?' , np.nan)
    year_3[i] = year_3[i].replace('?' , np.nan)
    year_4[i] = year_4[i].replace('?' , np.nan)
    year_5[i] = year_5[i].replace('?' , np.nan)

# %% [markdown]
# ###### since , some of the columns seems numerical value but thise values are string numerical values

# %%
#year_1.dtypes
#year_2.dtypes
#year_3.dtypes
#year_4.dtypes
#year_5.dtypes

# %%
year_1=year_1.apply(lambda col:pd.to_numeric(col,errors='coerce'))
year_2=year_2.apply(lambda col:pd.to_numeric(col,errors='coerce'))
year_3=year_3.apply(lambda col:pd.to_numeric(col,errors='coerce'))
year_4=year_4.apply(lambda col:pd.to_numeric(col,errors='coerce'))
year_5=year_5.apply(lambda col:pd.to_numeric(col,errors='coerce'))

# %%
#year_1.dtypes
#year_2.dtypes
#year_3.dtypes
#year_4.dtypes
#year_5.dtypes

# %% [markdown]
# ## 1. Steps of Data Exploration and Preparation

# %% [markdown]
# ### (a) missing data identification

# %%
print(" count of missing data in each attribute of year 1 data")
vars_with_na = [var for var in year_1.columns if year_1[var].isnull().sum() > 0]
year_1[vars_with_na].isnull().mean()
# Out:
#  count of missing data in each attribute of year 1 data
# Attr1     0.000428
# Attr2     0.000428
# Attr3     0.000428
# Attr4     0.004278
# Attr5     0.001141
# Attr6     0.000428
# Attr7     0.000428
# Attr8     0.003565
# Attr9     0.000143
# Attr10    0.000428
# Attr11    0.005419
# Attr12    0.004278
# Attr14    0.000428
# Attr15    0.000285
# Attr16    0.003565
# Attr17    0.003565
# Attr18    0.000428
# Attr21    0.230890
# Attr22    0.000428
# Attr24    0.017684
# Attr25    0.000428
# Attr26    0.003565
# Attr27    0.043069
# Attr28    0.004849
# Attr29    0.000428
# Attr32    0.005419
# Attr33    0.004278
# Attr34    0.003565
# Attr35    0.000428
# Attr36    0.000428
# Attr37    0.390188
# Attr38    0.000428
# Attr40    0.004278
# Attr41    0.011979
# Attr45    0.019110
# Attr46    0.004421
# Attr47    0.004136
# Attr48    0.000428
# Attr50    0.003565
# Attr51    0.000428
# Attr52    0.004136
# Attr53    0.004849
# Attr54    0.004849
# Attr57    0.000143
# ...

# %%
print(" count of missing data in each attribute of year 2 data")
vars_with_na = [var for var in year_2.columns if year_2[var].isnull().sum() > 0]
year_2[vars_with_na].isnull().mean()
# Out:
#  count of missing data in each attribute of year 2 data
# Attr1     0.000098
# Attr2     0.000098
# Attr3     0.000098
# Attr4     0.002163
# Attr5     0.002359
#             ...
# Attr60    0.053377
# Attr61    0.001573
# Attr62    0.006193
# Attr63    0.002163
# Attr64    0.020839
# Length: 64, dtype: float64

# %%
print(" count of missing data in each attribute of year 3 data")
vars_with_na = [var for var in year_3.columns if year_3[var].isnull().sum() > 0]
year_3[vars_with_na].isnull().mean()
# Out:
#  count of missing data in each attribute of year 3 data
# Attr4     0.001718
# Attr5     0.002386
# Attr8     0.001336
# Attr9     0.000286
# Attr12    0.001718
# Attr13    0.004009
# Attr15    0.000764
# Attr16    0.001336
# Attr17    0.001336
# Attr19    0.004009
# Attr20    0.004009
# Attr21    0.076460
# Attr23    0.004009
# Attr24    0.021669
# Attr26    0.001336
# Attr27    0.067201
# Attr28    0.021669
# Attr30    0.004009
# Attr31    0.004009
# Attr32    0.009641
# Attr33    0.001718
# Attr34    0.001336
# Attr37    0.450935
# Attr39    0.004009
# Attr40    0.001718
# Attr41    0.019282
# Attr42    0.004009
# Attr43    0.004009
# Attr44    0.004009
# Attr45    0.056319
# Attr46    0.001718
# Attr47    0.008209
# Attr49    0.004009
# Attr50    0.001336
# Attr52    0.008209
# Attr53    0.021669
# Attr54    0.021669
# Attr56    0.004009
# Attr58    0.002673
# Attr60    0.056415
# Attr61    0.001623
# Attr62    0.004009
# Attr63    0.001718
# Attr64    0.021669
# dtype: float64

# %%
print(" count of missing data in each attribute of year 4 data")
vars_with_na = [var for var in year_4.columns if year_4[var].isnull().sum() > 0]
year_4[vars_with_na].isnull().mean()
# Out:
#  count of missing data in each attribute of year 4 data
# Attr1     0.000105
# Attr2     0.000105
# Attr3     0.000105
# Attr4     0.004403
# Attr5     0.002097
#             ...
# Attr60    0.063214
# Attr61    0.003250
# Attr62    0.002201
# Attr63    0.004403
# Attr64    0.023483
# Length: 62, dtype: float64

# %%
print(" count of missing data in each attribute of year 5 data")
vars_with_na = [var for var in year_5.columns if year_5[var].isnull().sum() > 0]
year_5[vars_with_na].isnull().mean()
# Out:
#  count of missing data in each attribute of year 5 data
# Attr1     0.000553
# Attr2     0.000553
# Attr3     0.000553
# Attr4     0.003870
# Attr5     0.001843
# Attr6     0.000553
# Attr7     0.000553
# Attr8     0.003317
# Attr9     0.000184
# Attr10    0.000553
# Attr11    0.000553
# Attr12    0.003870
# Attr14    0.000553
# Attr15    0.001106
# Attr16    0.003317
# Attr17    0.003317
# Attr18    0.000553
# Attr21    0.018979
# Attr22    0.000553
# Attr24    0.000553
# Attr25    0.000553
# Attr26    0.003317
# Attr27    0.068178
# Attr28    0.018611
# Attr29    0.000553
# Attr32    0.007555
# Attr33    0.003870
# Attr34    0.003317
# Attr35    0.000553
# Attr36    0.000553
# Attr37    0.432652
# Attr38    0.000553
# Attr40    0.003870
# Attr41    0.014373
# Attr45    0.048093
# Attr46    0.003870
# Attr47    0.005712
# Attr48    0.000553
# Attr50    0.003317
# Attr51    0.000553
# Attr52    0.005896
# Attr53    0.018611
# Attr54    0.018611
# Attr57    0.000553
# ...

# %% [markdown]
# # -------------------------------- analysis of first year data---------------------------------------

# %%
year_1['class'].unique()  #it shows that there is no missing in target section
# Out:
# array([0, 1], dtype=int64)

# %%
# for plotting
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
variables = year_1.columns

# %%
# plot the histograms to have a quick look at the variable distribution
# histogram and Q-Q plots

def diagnostic_plots(df, variable):
    
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
#here i m checking for the normality of numerical values before encoding i applied , no of the numerical variable is normaly distributed 
for i in variables:
    diagnostic_plots(year_1, i)
# Out:
# C:\Users\SAKET NANDAN\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\SAKET NANDAN\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\SAKET NANDAN\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\SAKET NANDAN\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\SAKET NANDAN\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# ...

# %% [markdown]
# ###### similarly we can check spread of each columns of each year

# %% [markdown]
# # --------------------------insights of each year data------------------------------------------------

# %% [markdown]
# ###### now i m combining each  year data into one dataframe so that we can visulize each year's particular feature impact on bankruptcy

# %%
year_1['for_year']=1
year_2['for_year']=2
year_3['for_year']=3
year_4['for_year']=4
year_5['for_year']=5

# %%
common_1=year_1.append(year_2, ignore_index=True).copy()

# %%
common_2=common_1.append(year_3,ignore_index=True).copy()

# %%
common_3=common_2.append(year_4,ignore_index=True).copy()

# %%
common_4=common_3.append(year_5,ignore_index=True).copy()

# %%
common=common_4.copy()

# %%
common
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 42622  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 42623 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 42624 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 42625 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 42626 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr57   Attr58    Attr59    Attr60  \
# ...

# %%
#bankrupt
bankrupt=common[common['class']==1]

# %%
non_bankrupt=common[common['class']==0]

# %% [markdown]
# ## 1. impact of net profit / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr1',index='class',columns=['for_year']).plot.bar(title='(net profit / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr1',index='class',columns=['for_year']).plot.bar(title='(net profit/total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ###### (a) net profit / total assets  of bank-rupted companines is in -ve (it means these companies are going in loss)
# ###### (b) -> companies forcasted in 5th year is in big loss in comparision to other years
# ######      -> companies forcasted in 1st year is also in loss but in 2nd ,3rd,4th year are in little good position but in little loss
# ###### (c) for non-bankrupted companies maxm profit is shown by companies forcasted in 5th year

# %% [markdown]
# ## 2. impact of total liabilities / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr2',index='class',columns=['for_year']).plot.bar(title='(total liabilities / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr2',index='class',columns=['for_year']).plot.bar(title='(total liabilities / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ###### (a) if we compare both graph then , minimum total liabilities/total assets on non-bank-rupted companies are less than minum total liabilities/total assets of bank rupted companies .
# ###### (b) liabilities/asstes of companies forcatsed in 1st year is highest for bank-rupted companies .
# ###### (c) liabilities of companies forcasted for 5th year in both bankrupted and non-bankrupted is minimum

# %% [markdown]
# ## 3. impact of working capital / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr3',index='class',columns=['for_year']).plot.bar(title='(working capital / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr3',index='class',columns=['for_year']).plot.bar(title='(working capital / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ###### The capital of a business which is used in its day-to-day trading operations, calculated as the current assets minus the current liabilities.
# ###### (a) working capital /total assets where least for bankrupted companies for the  1st  year forcasted data , its shows that if u r not putting capital in day to day trading operations then there is high risk bank ruptcy
# ###### (b) working capital investement is highest for 5th year forcasted companines for non-bankrupted organizations

# %% [markdown]
# ## 4. impact of current assets / short-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr4',index='class',columns=['for_year']).plot.bar(title='(current assets / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr4',index='class',columns=['for_year']).plot.bar(title='(current assets / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ###### short time libalities :- A short-term liability is a financial obligation that is to be paid within some short period of time (year , 6 month..)
# ###### (a) if w see then year for both bankrupted and non-bankrupted for 3rd year its value is high after that this ratio has fall down and fall is high for the 5th year
# ###### (b) for bankrupted company current assets/short time liabilities is nearly stagnent where as for non-bankrupted companies increased till 3rd year then fall down

# %% [markdown]
# ## 5. impact of [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation) * 365] on bankruptcy

# %%
bankrupt.pivot_table('Attr5',index='class',columns=['for_year']).plot.bar(title='[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365 of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr5',index='class',columns=['for_year']).plot.bar(title='[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365 of non_bank-rupted company year wise')

# %% [markdown]
# ## 6. impact of retained earnings / total assets on bank-ruptcy

# %%
bankrupt.pivot_table('Attr6',index='class',columns=['for_year']).plot.bar(title='(retained earnings / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr6',index='class',columns=['for_year']).plot.bar(title='(retained earnings / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 7. impact of EBIT / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr7',index='class',columns=['for_year']).plot.bar(title='(EBIT / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr7',index='class',columns=['for_year']).plot.bar(title='(EBIT / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 8.impact of (book value of equity / total liabilities) on bank ruptcy

# %%
bankrupt.pivot_table('Attr8',index='class',columns=['for_year']).plot.bar(title='(book value of equity / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr8',index='class',columns=['for_year']).plot.bar(title='(book value of equity / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 9. impact of sales / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr9',index='class',columns=['for_year']).plot.bar(title='(sales / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr9',index='class',columns=['for_year']).plot.bar(title='(sales / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 10. impact of  equity / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr10',index='class',columns=['for_year']).plot.bar(title='(equity / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr10',index='class',columns=['for_year']).plot.bar(title='(equity / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 11. impact of (gross profit + extraordinary items + financial expenses) / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr11',index='class',columns=['for_year']).plot.bar(title='((gross profit + extraordinary items + financial expenses) / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr11',index='class',columns=['for_year']).plot.bar(title='((gross profit + extraordinary items + financial expenses) / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 12. impact of (gross profit / short-term liabilities ) on bankruptcy

# %%
bankrupt.pivot_table('Attr12',index='class',columns=['for_year']).plot.bar(title='(gross profit / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr12',index='class',columns=['for_year']).plot.bar(title='(gross profit / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 13. impact of ((gross profit + depreciation) / sales) on bankruptcy

# %%
bankrupt.pivot_table('Attr13',index='class',columns=['for_year']).plot.bar(title='((gross profit + depreciation) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr13',index='class',columns=['for_year']).plot.bar(title='((gross profit + depreciation) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 14. impact of (gross profit + interest) / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr14',index='class',columns=['for_year']).plot.bar(title='((gross profit + interest) / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr14',index='class',columns=['for_year']).plot.bar(title='((gross profit + interest) / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 15 . impact of (total liabilities * 365) / (gross profit + depreciation)  on bankruptcy

# %%
bankrupt.pivot_table('Attr15',index='class',columns=['for_year']).plot.bar(title='((total liabilities * 365) / (gross profit + depreciation)) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr15',index='class',columns=['for_year']).plot.bar(title='((total liabilities * 365) / (gross profit + depreciation)) of non_bank-rupted company year wise')

# %% [markdown]
# ## 16. impact of (gross profit + depreciation) / total liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr16',index='class',columns=['for_year']).plot.bar(title='((gross profit + depreciation) / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr16',index='class',columns=['for_year']).plot.bar(title='((gross profit + depreciation) / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 17. impact of total assets / total liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr17',index='class',columns=['for_year']).plot.bar(title='(total assets / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr17',index='class',columns=['for_year']).plot.bar(title='(total assets / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 18. impact of gross profit / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr18',index='class',columns=['for_year']).plot.bar(title='(gross profit / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr18',index='class',columns=['for_year']).plot.bar(title='(gross profit / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 19. impact of gross profit / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr19',index='class',columns=['for_year']).plot.bar(title='(gross profit / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr19',index='class',columns=['for_year']).plot.bar(title='(gross profit / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 20 . impact of (inventory * 365) / sales  on bankruptcy

# %%
bankrupt.pivot_table('Attr20',index='class',columns=['for_year']).plot.bar(title='((inventory * 365) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr20',index='class',columns=['for_year']).plot.bar(title='((inventory * 365) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 21. impact of sales (n) / sales (n-1)  on bankruptcy

# %%
bankrupt.pivot_table('Attr21',index='class',columns=['for_year']).plot.bar(title='(sales (n) / sales (n-1)) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr21',index='class',columns=['for_year']).plot.bar(title='(sales (n) / sales (n-1)) of non_bank-rupted company year wise')

# %% [markdown]
# ## 22 . impact of profit on operating activities / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr22',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr22',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 23 . impact of  on bankruptcy

# %%
bankrupt.pivot_table('Attr23',index='class',columns=['for_year']).plot.bar(title='(net profit / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr23',index='class',columns=['for_year']).plot.bar(title='(net profit / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 24 . impact of gross profit (in 3 years) / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr24',index='class',columns=['for_year']).plot.bar(title='(gross profit (in 3 years) / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr24',index='class',columns=['for_year']).plot.bar(title='(gross profit (in 3 years) / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 25 . impact of (equity - share capital) / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr25',index='class',columns=['for_year']).plot.bar(title='((equity - share capital) / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr25',index='class',columns=['for_year']).plot.bar(title='((equity - share capital) / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 26. impact of (net profit + depreciation) / total liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr26',index='class',columns=['for_year']).plot.bar(title='((net profit + depreciation) / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr26',index='class',columns=['for_year']).plot.bar(title='((net profit + depreciation) / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 27. impact of profit on operating activities / financial expenses on bankruptcy

# %%
bankrupt.pivot_table('Attr27',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / financial expenses) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr27',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / financial expenses) of non_bank-rupted company year wise')

# %% [markdown]
# ## 28 . impact of working capital / fixed assets on bankruptcy

# %%
bankrupt.pivot_table('Attr28',index='class',columns=['for_year']).plot.bar(title='(working capital / fixed assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr28',index='class',columns=['for_year']).plot.bar(title='(working capital / fixed assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 29 . impact of total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr29',index='class',columns=['for_year']).plot.bar(title='(total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr29',index='class',columns=['for_year']).plot.bar(title='(total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 30 . impact of  (total liabilities - cash) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr30',index='class',columns=['for_year']).plot.bar(title='((total liabilities - cash) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr30',index='class',columns=['for_year']).plot.bar(title='((total liabilities - cash) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 31 . impact of (gross profit + interest) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr31',index='class',columns=['for_year']).plot.bar(title='((gross profit + interest) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr31',index='class',columns=['for_year']).plot.bar(title='((gross profit + interest) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ##  32. impact of (current liabilities * 365) / cost of products sold on bankruptcy

# %%
bankrupt.pivot_table('Attr32',index='class',columns=['for_year']).plot.bar(title='((current liabilities * 365) / cost of products sold) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr32',index='class',columns=['for_year']).plot.bar(title='((current liabilities * 365) / cost of products sold) of non_bank-rupted company year wise')

# %% [markdown]
# ## 33 . impact of operating expenses / short-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr33',index='class',columns=['for_year']).plot.bar(title='(operating expenses / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr33',index='class',columns=['for_year']).plot.bar(title='(operating expenses / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 34. impact of operating expenses / total liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr34',index='class',columns=['for_year']).plot.bar(title='(operating expenses / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr34',index='class',columns=['for_year']).plot.bar(title='(operating expenses / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 35. impact of profit on sales / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr35',index='class',columns=['for_year']).plot.bar(title='(profit on sales / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr35',index='class',columns=['for_year']).plot.bar(title='(profit on sales / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 36 . impact of  total sales / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr36',index='class',columns=['for_year']).plot.bar(title='(total sales / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr36',index='class',columns=['for_year']).plot.bar(title='(total sales / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ##  37. impact of (current assets - inventories) / long-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr37',index='class',columns=['for_year']).plot.bar(title='((current assets - inventories) / long-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr37',index='class',columns=['for_year']).plot.bar(title='((current assets - inventories) / long-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 38. impact of constant capital / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr38',index='class',columns=['for_year']).plot.bar(title='(constant capital / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr38',index='class',columns=['for_year']).plot.bar(title='(constant capital / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 39. impact of profit on sales / sales  on bankruptcy

# %%
bankrupt.pivot_table('Attr39',index='class',columns=['for_year']).plot.bar(title='(profit on sales / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr39',index='class',columns=['for_year']).plot.bar(title='(profit on sales / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 40. impact of (current assets - inventory - receivables) / short-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr40',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory - receivables) / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr40',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory - receivables) / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 41. impact of total liabilities / ((profit on operating activities + depreciation) * (12/365)) on bankruptcy

# %%
bankrupt.pivot_table('Attr41',index='class',columns=['for_year']).plot.bar(title='(total liabilities / ((profit on operating activities + depreciation) * (12/365))) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr41',index='class',columns=['for_year']).plot.bar(title='(total liabilities / ((profit on operating activities + depreciation) * (12/365))) of non_bank-rupted company year wise')

# %% [markdown]
# ## 42 . impact of  on bankruptcy

# %%
bankrupt.pivot_table('Attr42',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr42',index='class',columns=['for_year']).plot.bar(title='(profit on operating activities / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 43 . impact of rotation receivables + inventory turnover in days on bankruptcy

# %%
bankrupt.pivot_table('Attr43',index='class',columns=['for_year']).plot.bar(title='(rotation receivables + inventory turnover in days) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr43',index='class',columns=['for_year']).plot.bar(title='(vrotation receivables + inventory turnover in days) of non_bank-rupted company year wise')

# %% [markdown]
# ## 44. impact of (receivables * 365) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr44',index='class',columns=['for_year']).plot.bar(title='((receivables * 365) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr44',index='class',columns=['for_year']).plot.bar(title='((receivables * 365) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 45. impact of net profit / inventory on bankruptcy

# %%
bankrupt.pivot_table('Attr45',index='class',columns=['for_year']).plot.bar(title='(net profit / inventory) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr45',index='class',columns=['for_year']).plot.bar(title='(net profit / inventory) of non_bank-rupted company year wise')

# %% [markdown]
# ## 46. impact of (current assets - inventory) / short-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr46',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory) / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr46',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory) / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 47. impact of  (inventory * 365) / cost of products sold on bankruptcy

# %%
bankrupt.pivot_table('Attr47',index='class',columns=['for_year']).plot.bar(title='((inventory * 365) / cost of products sold) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr47',index='class',columns=['for_year']).plot.bar(title='((inventory * 365) / cost of products sold) of non_bank-rupted company year wise')

# %% [markdown]
# ## 48. impact of EBITDA (profit on operating activities - depreciation) / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr48',index='class',columns=['for_year']).plot.bar(title='(EBITDA (profit on operating activities - depreciation) / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr48',index='class',columns=['for_year']).plot.bar(title='(EBITDA (profit on operating activities - depreciation) / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 49 . impact of EBITDA (profit on operating activities - depreciation) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr49',index='class',columns=['for_year']).plot.bar(title='(EBITDA (profit on operating activities - depreciation) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr49',index='class',columns=['for_year']).plot.bar(title='(EBITDA (profit on operating activities - depreciation) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 50. impact of current assets / total liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr50',index='class',columns=['for_year']).plot.bar(title='(current assets / total liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr50',index='class',columns=['for_year']).plot.bar(title='(current assets / total liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 51. impact of short-term liabilities / total assets on bankruptcy

# %%
bankrupt.pivot_table('Attr51',index='class',columns=['for_year']).plot.bar(title='(short-term liabilities / total assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr51',index='class',columns=['for_year']).plot.bar(title='(short-term liabilities / total assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 52. impact of (short-term liabilities * 365) / cost of products sold) on bankruptcy

# %%
bankrupt.pivot_table('Attr52',index='class',columns=['for_year']).plot.bar(title='((short-term liabilities * 365) / cost of products sold)) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr52',index='class',columns=['for_year']).plot.bar(title='((short-term liabilities * 365) / cost of products sold)) of non_bank-rupted company year wise')

# %% [markdown]
# ## 53 . impact of equity / fixed assets on bankruptcy

# %%
bankrupt.pivot_table('Attr53',index='class',columns=['for_year']).plot.bar(title='(equity / fixed assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr53',index='class',columns=['for_year']).plot.bar(title='(equity / fixed assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 54. impact of constant capital / fixed assets on bankruptcy

# %%
bankrupt.pivot_table('Attr54',index='class',columns=['for_year']).plot.bar(title='(constant capital / fixed assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr54',index='class',columns=['for_year']).plot.bar(title='(constant capital / fixed assets) of non_bank-rupted company year wise')

# %% [markdown]
# ## 55. impact of working capital on bankruptcy

# %%
bankrupt.pivot_table('Attr55',index='class',columns=['for_year']).plot.bar(title='(working capital) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr55',index='class',columns=['for_year']).plot.bar(title='(working capital) of non_bank-rupted company year wise')

# %% [markdown]
# ## 56. impact of (sales - cost of products sold) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr56',index='class',columns=['for_year']).plot.bar(title='((sales - cost of products sold) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr56',index='class',columns=['for_year']).plot.bar(title='((sales - cost of products sold) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 57. impact of (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation) on bankruptcy

# %%
bankrupt.pivot_table('Attr57',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr57',index='class',columns=['for_year']).plot.bar(title='((current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)) of non_bank-rupted company year wise')

# %% [markdown]
# ## 58. impact of total costs /total sales on bankruptcy

# %%
bankrupt.pivot_table('Attr58',index='class',columns=['for_year']).plot.bar(title='(total costs /total sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr58',index='class',columns=['for_year']).plot.bar(title='(total costs /total sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 59. impact of long-term liabilities / equity on bankruptcy

# %%
bankrupt.pivot_table('Attr59',index='class',columns=['for_year']).plot.bar(title='(long-term liabilities / equity) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr59',index='class',columns=['for_year']).plot.bar(title='(long-term liabilities / equity) of non_bank-rupted company year wise')

# %% [markdown]
# ## 60. impact of sales / inventory on bankruptcy

# %%
bankrupt.pivot_table('Attr60',index='class',columns=['for_year']).plot.bar(title='(sales / inventory) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr60',index='class',columns=['for_year']).plot.bar(title='(sales / inventory) of non_bank-rupted company year wise')

# %% [markdown]
# ## 61. impact of sales / receivables on bankruptcy

# %%
bankrupt.pivot_table('Attr61',index='class',columns=['for_year']).plot.bar(title='(sales / receivables) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr61',index='class',columns=['for_year']).plot.bar(title='(sales / receivables) of non_bank-rupted company year wise')

# %% [markdown]
# ## 62. impact of (short-term liabilities *365) / sales on bankruptcy

# %%
bankrupt.pivot_table('Attr62',index='class',columns=['for_year']).plot.bar(title='((short-term liabilities *365) / sales) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr62',index='class',columns=['for_year']).plot.bar(title='((short-term liabilities *365) / sales) of non_bank-rupted company year wise')

# %% [markdown]
# ## 63. impact of sales / short-term liabilities on bankruptcy

# %%
bankrupt.pivot_table('Attr63',index='class',columns=['for_year']).plot.bar(title='(sales / short-term liabilities) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr63',index='class',columns=['for_year']).plot.bar(title='(sales / short-term liabilities) of non_bank-rupted company year wise')

# %% [markdown]
# ## 64. impact of sales / fixed assets on bankruptcy

# %%
bankrupt.pivot_table('Attr64',index='class',columns=['for_year']).plot.bar(title='(sales / fixed assets) of bank-rupted company year wise ')
non_bankrupt.pivot_table('Attr64',index='class',columns=['for_year']).plot.bar(title='(sales / fixed assets) of non_bank-rupted company year wise')
